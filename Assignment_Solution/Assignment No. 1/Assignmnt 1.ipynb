# %%
print("Hello", "World", 123)
print("Apple", "Banana", "Mango", sep="-")
print("Hello", end=" ")
print("World")
# Out:
# Hello World 123
# Apple-Banana-Mango
# Hello World

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Hello Hunar
