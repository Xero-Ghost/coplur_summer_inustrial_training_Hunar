# %%
import csv
filename = "address_book.csv"
records = []

n = int(input("Enter number of records: "))

for i in range(n):
    name = input("Enter Name: ")
    address = input("Enter Address: ")
    mobile = input("Enter Mobile Number: ")
    email = input("Enter Email: ")
    records.append([name, address, mobile, email])

with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Address", "Mobile", "Email"])
    writer.writerows(records)

print("Data written to", filename)

with open(filename, mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# Data written to address_book.csv
# ['Name', 'Address', 'Mobile', 'Email']
# ['Hunar', 'xyz', '1234', 'h@gmail.com']
# ['Mukul', 'were', '3452', 'm@gmail.com']
# ['Ana', 'fgh', '5231', 'a@gmail.com']

# %%
import sqlite3
conn = sqlite3.connect("CollegeDB.db")
cursor = conn.cursor()
cursor.execute("""
CREATE TABLE Student (
    StudentID INTEGER PRIMARY KEY,
    Name TEXT,
    Course TEXT,
    Age INTEGER
)
""")
cursor.execute("""
CREATE TABLE Faculty (
    FacultyID INTEGER PRIMARY KEY,
    FacultyName TEXT,
    Subject TEXT
)
""")
cursor.execute("""
CREATE TABLE Department (
    DeptID INTEGER PRIMARY KEY,
    DeptName TEXT
)
""")
conn.commit()
cursor.execute("INSERT INTO Student VALUES (1, 'Rahul', 'BTech', 20)")
cursor.execute("INSERT INTO Student VALUES (2, 'Aman', 'BCA', 19)")
cursor.execute("INSERT INTO Student VALUES (3, 'Priya', 'MCA', 22)")
cursor.execute("INSERT INTO Faculty VALUES (101, 'Dr. Sharma', 'DBMS')")
cursor.execute("INSERT INTO Faculty VALUES (102, 'Prof. Verma', 'Python')")
cursor.execute("INSERT INTO Department VALUES (1, 'Computer Science')")
cursor.execute("INSERT INTO Department VALUES (2, 'Information Technology')")
conn.commit()
cursor.execute("SELECT * FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)
cursor.execute("SELECT Name, Course FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)
cursor.execute("SELECT * FROM Student WHERE Age > 20")
rows = cursor.fetchall()
for row in rows:
    print(row)
cursor.execute("""
UPDATE Student
SET Age = 21
WHERE StudentID = 1
""")
conn.commit()
cursor.execute("""
DELETE FROM Student
WHERE StudentID = 2
""")
conn.commit()
cursor.execute("SELECT * FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)
conn.close()
# Out:
# (1, 'Rahul', 'BTech', 20)
# (2, 'Aman', 'BCA', 19)
# (3, 'Priya', 'MCA', 22)
# ('Rahul', 'BTech')
# ('Aman', 'BCA')
# ('Priya', 'MCA')
# (3, 'Priya', 'MCA', 22)
# (1, 'Rahul', 'BTech', 21)
# (3, 'Priya', 'MCA', 22)
