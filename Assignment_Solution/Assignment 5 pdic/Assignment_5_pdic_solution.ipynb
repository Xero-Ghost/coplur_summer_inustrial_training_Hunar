# %%
t1 = (1, 2, 3)
print("1)", t1 * 3)

t2 = (4, 5)
t3 = (6, 7)
t4 = (8, 9)
joined_tuple = t1 + t2 + t3
print("2)", joined_tuple)

element = 2
print("3)", element in t1)

numbers = (12, 5, 19, 3, 8, 15)

total = 0
highest = numbers[0]
lowest = numbers[0]

for num in numbers:
    total += num
    if num > highest:
        highest = num
    if num < lowest:
        lowest = num

print("4) Total:", total)
print("   Highest:", highest)
print("   Lowest:", lowest)

n = (3, 14, 7, 22, 9, 41, 18, 5)
filtered = tuple(x for x in n if x > 10)
print("5)", filtered)

s = {"cat", "dog", "bird", "fish"}
count = 0
for item in s:
    count += 1
print("6)", count)

set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
combined = set1 | set2
print("7)", combined)

common = set1 & set2
print("8)", common)

either_only = set1 ^ set2
print("9)", either_only)
# Out:
# 1) (1, 2, 3, 1, 2, 3, 1, 2, 3)
# 2) (1, 2, 3, 4, 5, 6, 7)
# 3) True
# 4) Total: 62
#    Highest: 19
#    Lowest: 3
# 5) (14, 22, 41, 18)
# 6) 4
# 7) {1, 2, 3, 4, 5, 6}
# 8) {3, 4}
# 9) {1, 2, 5, 6}
