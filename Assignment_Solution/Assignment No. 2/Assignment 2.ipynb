# %%
student = {
    "name": "Hunar",
    "age": 24,
    "branch": "AI"
}
print("Dictionary:")
print(student)
print("Name:", student["name"])
student["college"] = "SKIT"
student["age"] = 21
student.pop("branch")
print("Updated Dictionary:", student)
colors = ("red", "green", "blue")
print("Tuple:")
print(colors)
print("First Color:", colors[0])
data = (1, "Hunar", 95.5)
print("Mixed Tuple:", data)
numbers = {1, 2, 3, 4, 4, 5}
print("Set:")
print(numbers)
numbers.add(6)
numbers.remove(2)
print("Updated Set:", numbers)
# Out:
# Dictionary:
# {'name': 'Hunar', 'age': 24, 'branch': 'AI'}
# Name: Hunar
# Updated Dictionary: {'name': 'Hunar', 'age': 21, 'college': 'SKIT'}
# Tuple:
# ('red', 'green', 'blue')
# First Color: red
# Mixed Tuple: (1, 'Hunar', 95.5)
# Set:
# {1, 2, 3, 4, 5}
# Updated Set: {1, 3, 4, 5, 6}

# %%
while True:
    print("Basic Math Operations")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 5:
        print("Program Ended")
        break
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    if choice == 1:
        print("Addition =", num1 + num2)
    elif choice == 2:
        print("Subtraction =", num1 - num2)
    elif choice == 3:
        print("Multiplication =", num1 * num2)
    elif choice == 4:
        if num2 != 0:
            print("Division =", num1 / num2)
        else:
            print("Division by zero is not possible")
    else:
        print("Invalid Choice try again")
# Out:
# Basic Math Operations
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Division = 10.0
# Basic Math Operations
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Program Ended

# %%
s = input("Enter a number: ")
rev = s[-1::-1]
if s== rev:
    print("Given number is palindrome.")
else:
    print("Given number is not palindrome.")
# Out:
# Given number is not palindrome.
